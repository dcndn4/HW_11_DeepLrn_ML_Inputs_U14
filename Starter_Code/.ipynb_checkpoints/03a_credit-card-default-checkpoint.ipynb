# %%
# 11:05 AM
# 11:25 AM
# 11:35 AM
import os; print(os.path.dirname(os.getcwd()).split('\\')[-1])

# There is an M1 version of this code available! If it doesn't work, you should be able to use Google Colab
# What you do is go Google Colab, upload the notebook, and upload the .csv files when prompted. It's pretty seamless.
# Out:
# 03-Stu_CC_Default

# %% [markdown]
# # Students Do: Preventing credit card defaults with neural networks
#
# In this activity, you will train a neural network model to predict whether a credit card holder will default in the next month.
#
# The dataset provided contains `30,000` anonymous records of credit default status with `23` features columns and one binary target column entitled _DEFAULT_, where `1` represents a defaulted credit card.
#
# The `23` features include demographic info (age, gender, marital status, etc.), credit limit, past payment details, and other relevant information.
#
# You are tasked to create a neural network model to predict if a credit card holder will default.

# %%
# Initial imports
import pandas as pd
from path import Path
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %% [markdown]
# <font color='red'>@@@</font>
#
# Set a random seed so we can compare models with different hyperparameters set. Apples to apples.
#
# <font color='red'>@@@</font>

# %%
# Set a random seed for TensorFlow to allow reproducible testing results
tf.random.set_seed(126)

# %% [markdown]
# ## Instructions
#
# 1. Load the data in a Pandas DataFrame.

# %%
# Read in data
file_path = Path("../Resources/cc_default.csv")
df = pd.read_csv(file_path)
df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...           "BILL_AMT4"  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0     -2  ...                     0          0          0         0       689
# 1      0  ...                  3272       3455       3261         0      1000
# 2      0  ...                 14331      14948      15549      1518      1500
# 3      0  ...                 28314      28959      29547      2000      2019
# 4      0  ...                 20940      19146      19131      2000     36681
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  DEFAULT
# 0         0         0         0         0        1
# 1      1000      1000         0      2000        1
# 2      1000      1000      1000      5000        0
# 3      1200      1100      1069      1000        0
# 4     10000      9000       689       679        0
#
# [5 rows x 24 columns]

# %% [markdown]
# 2. Define the features set `X` by including all the columns of the DataFrame except the `DEFAULT` column.

# %%
# Define features data
X = df.copy()
X = X.drop(columns=["DEFAULT"])
X.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT3           "BILL_AMT4"  BILL_AMT5  BILL_AMT6  \
# 0     -2  ...        689                     0          0          0
# 1      0  ...       2682                  3272       3455       3261
# 2      0  ...      13559                 14331      14948      15549
# 3      0  ...      49291                 28314      28959      29547
# 4      0  ...      35835                 20940      19146      19131
#
#    PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 0         0       689         0         0         0         0
# 1         0      1000      1000      1000         0      2000
# 2      1518      1500      1000      1000      1000      5000
# 3      2000      2019      1200      1100      1069      1000
# 4      2000     36681     10000      9000       689       679
#
# [5 rows x 23 columns]

# %% [markdown]
# 3. Create the target vector `y` by assigning the values of the `DEFAULT` column of the DataFrame.

# %%
# Define target data
y = df["DEFAULT"].values
y = y.reshape(-1, 1)
y[:5]
# Out:
# array([[1],
#        [1],
#        [0],
#        [0],
#        [0]], dtype=int64)

# %% [markdown]
# 4. Create the training an testing sets using the `train_test_split` function from `sklearn`.

# %%
# Create training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %% [markdown]
# 5. Scale the features data using the `StandardScaler` from `sklearn`.

# %%
# Create the scaler instance
X_scaler = StandardScaler()

# %%
# Fit the scaler
X_scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
# Scale the features data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# 6. Create a neural network model with `23` inputs, one hidden layer with `69` units, and an output layer with a single output. Use the `relu` activation function for the first layer and `sigmoid` for the second layer.

# %% [markdown]
# <font color='red'>@@@</font>
#
# We have 23 inputs (columns). Using the 3x rule of thumb, 3x23 = 69.
#
# <font color='red'>@@@</font>

# %%
# Define the model
number_inputs = 23
number_hidden_nodes = 69

nn = Sequential()
nn.add(Dense(units=number_hidden_nodes, input_dim=number_inputs, activation="relu"))
nn.add(Dense(1, activation="sigmoid"))

# %% [markdown]
# 7. Compile the neural network model using the `binary_crossentropy` loss function, the `adam` optimizer, and `accuracy` as additional metric.

# %%
# Compile model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %% [markdown]
# 704/704 [==============================] - 1s 860us/step - loss: 0.4079 - accuracy: 0.8252
# Epoch 93/100
# 704/704 [==============================] - 1s 856us/step - loss: 0.4087 - accuracy: 0.8271
# Epoch 94/100
# 704/704 [==============================] - 1s 873us/step - loss: 0.4083 - accuracy: 0.8259
# Epoch 95/100
# 704/704 [==============================] - 1s 879us/step - loss: 0.4073 - accuracy: 0.8262
# Epoch 96/100
# 704/704 [==============================] - 1s 871us/step - loss: 0.4077 - accuracy: 0.8257
# Epoch 97/100
# 704/704 [==============================] - 1s 851us/step - loss: 0.4094 - accuracy: 0.8247
# Epoch 98/100
# 704/704 [==============================] - 1s 875us/step - loss: 0.4077 - accuracy: 0.8256
# Epoch 99/100
# 704/704 [==============================] - 1s 882us/step - loss: 0.4081 - accuracy: 0.8233
# Epoch 100/100
# 704/704 [==============================] - 1s 876us/step - loss: 0.4072 - accuracy: 0.8270

# %% [markdown]
# 9. Plot the loss function and accuracy.

# %%
# Create a dataframe with the history dictionary
df_plot = pd.DataFrame(model.history, index=range(1, len(model.history["loss"]) + 1))

# Plot the loss
df_plot.plot(y="loss")
# Out:
# <AxesSubplot:>

# %%
# Plot the accuracy
df_plot.plot(y="accuracy")
# Out:
# <AxesSubplot:>

# %% [markdown]
# 10. Evaluate the model using testing data and the `evaluate` method.

# %%
# Evaluate the model fit with linear dummy data
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 235/235 - 0s - loss: 0.4415 - accuracy: 0.8157 - 229ms/epoch - 974us/step
# Loss: 0.44147858023643494, Accuracy: 0.8157333135604858

# %% [markdown]
# ## Challenge
#
# For this challenge section, you have to figure out how the model you created could be modified to improve the accuracy.
#
# 1. Review the Keras documentation about activation functions, and decide if there is anyone that could be used instead of `sigmoid`.
#
# 2. Change any other parameter that you believe could improve the model's accuracy.
#
# 3. Evaluate the model's accuracy and loss and write down your conclusions.

# %%
# Define the model
number_inputs = 23
number_hidden_nodes = 120

nn_2 = Sequential()
nn_2.add(Dense(units=number_hidden_nodes, input_dim=number_inputs, activation="tanh"))
nn_2.add(Dense(units=1, activation="hard_sigmoid"))

# %%
# Compile model
nn_2.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model
model_2 = nn_2.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 704/704 [==============================] - 1s 812us/step - loss: 0.5166 - accuracy: 0.7860
# Epoch 2/100
# 704/704 [==============================] - 1s 800us/step - loss: 0.4817 - accuracy: 0.7942
# Epoch 3/100
# 704/704 [==============================] - 1s 787us/step - loss: 0.4647 - accuracy: 0.8001
# Epoch 4/100
# 704/704 [==============================] - 1s 895us/step - loss: 0.4622 - accuracy: 0.8028
# Epoch 5/100
# 704/704 [==============================] - 1s 861us/step - loss: 0.4960 - accuracy: 0.7924
# Epoch 6/100
# 704/704 [==============================] - 1s 797us/step - loss: 0.4691 - accuracy: 0.8045
# Epoch 7/100
# 704/704 [==============================] - 1s 820us/step - loss: 0.4559 - accuracy: 0.8055
# Epoch 8/100
# 704/704 [==============================] - 1s 884us/step - loss: 0.4559 - accuracy: 0.8061
# Epoch 9/100
# 704/704 [==============================] - 1s 914us/step - loss: 0.4492 - accuracy: 0.8076
# Epoch 10/100
# 704/704 [==============================] - 1s 844us/step - loss: 0.4496 - accuracy: 0.8082
# Epoch 11/100
# 704/704 [==============================] - 1s 829us/step - loss: 0.4510 - accuracy: 0.8074
# Epoch 12/100
# 704/704 [==============================] - 1s 787us/step - loss: 0.4480 - accuracy: 0.8099
# Epoch 13/100
# 704/704 [==============================] - 1s 875us/step - loss: 0.4186 - accuracy: 0.8218
# Epoch 76/100
# 704/704 [==============================] - 1s 859us/step - loss: 0.4231 - accuracy: 0.8216
# Epoch 77/100
# 704/704 [==============================] - 1s 819us/step - loss: 0.4987 - accuracy: 0.8023
# Epoch 78/100
# 704/704 [==============================] - 1s 846us/step - loss: 0.4234 - accuracy: 0.8215
# Epoch 79/100
# 704/704 [==============================] - 1s 787us/step - loss: 0.4194 - accuracy: 0.8218
# Epoch 80/100
# 704/704 [==============================] - 1s 797us/step - loss: 0.4194 - accuracy: 0.8222
# Epoch 81/100
# 704/704 [==============================] - 1s 807us/step - loss: 0.4178 - accuracy: 0.8213
# Epoch 82/100
# 704/704 [==============================] - 1s 832us/step - loss: 0.4179 - accuracy: 0.8218
# Epoch 83/100
# 704/704 [==============================] - 1s 772us/step - loss: 0.4183 - accuracy: 0.8213
# Epoch 84/100
# 704/704 [==============================] - 1s 784us/step - loss: 0.4184 - accuracy: 0.8214
# Epoch 85/100
# 704/704 [==============================] - 1s 807us/step - loss: 0.4204 - accuracy: 0.8219
# Epoch 86/100
# 704/704 [==============================] - 1s 786us/step - loss: 0.4179 - accuracy: 0.8216
# Epoch 87/100
# 704/704 [==============================] - 1s 838us/step - loss: 0.4240 - accuracy: 0.8216
# Epoch 88/100
# 704/704 [==============================] - 1s 788us/step - loss: 0.4176 - accuracy: 0.8224
# Epoch 89/100
# 704/704 [==============================] - 1s 823us/step - loss: 0.4397 - accuracy: 0.8200
# Epoch 90/100
# 704/704 [==============================] - 1s 879us/step - loss: 0.4180 - accuracy: 0.8223
# Epoch 91/100
# 704/704 [==============================] - 1s 798us/step - loss: 0.4153 - accuracy: 0.8220
# Epoch 92/100
# 704/704 [==============================] - 1s 821us/step - loss: 0.4166 - accuracy: 0.8224
# Epoch 93/100
# 704/704 [==============================] - 1s 810us/step - loss: 0.4172 - accuracy: 0.8222
# Epoch 94/100
# 704/704 [==============================] - 1s 808us/step - loss: 0.4201 - accuracy: 0.8206
# Epoch 95/100
# 704/704 [==============================] - 1s 803us/step - loss: 0.4160 - accuracy: 0.8221
# Epoch 96/100
# 704/704 [==============================] - 1s 805us/step - loss: 0.4150 - accuracy: 0.8226
# Epoch 97/100
# 704/704 [==============================] - 1s 770us/step - loss: 0.4145 - accuracy: 0.8225
# Epoch 98/100
# 704/704 [==============================] - 1s 816us/step - loss: 0.4170 - accuracy: 0.8224
# Epoch 99/100
# 704/704 [==============================] - 1s 776us/step - loss: 0.4162 - accuracy: 0.8231
# Epoch 100/100
# 704/704 [==============================] - 1s 826us/step - loss: 0.4146 - accuracy: 0.8232

# %%
# Evaluate the model fit with linear dummy data
model_loss_2, model_accuracy_2 = nn_2.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss_2}, Accuracy: {model_accuracy_2}")
# Out:
# 235/235 - 0s - loss: 0.4836 - accuracy: 0.8236 - 218ms/epoch - 928us/step
# Loss: 0.4836415648460388, Accuracy: 0.8235999941825867

# %% [markdown]
# ### Conclusions
#
# **Sample Answer:** After reviewing the activation functions documentation, I decided to use the `tanh` function for the first layer and the `hard_sigmoid` for the output layer. There is an slightly improvement in the model's accuracy that is worth to take this activation functions as a better option.
#
# We may test with different functions or even perform PCA as part of the possible optimizations.
